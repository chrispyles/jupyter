# %%
from datascience import *
import numpy as np

import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import warnings
warnings.simplefilter('ignore', FutureWarning)

# regression functions
def standard_units(arr):
    return (arr - np.mean(arr)) / np.std(arr)

def correlation(x, y):
    return np.mean(standard_units(x) * standard_units(y))

def slope(x, y):
    r = correlation(x, y)
    return r * np.std(y) / np.std(x)

def intercept(x, y):
    m = slope(x, y)
    return np.mean(y) - m * np.mean(x)

# read table
jaipur = Table.read_table('jaipur.csv')

# %%
jaipur
# Out:
# date       | meantempm | meandewptm | meanpressurem | maxhumidity | minhumidity | maxtempm | mintempm | maxdewptm | mindewptm | maxpressurem | minpressurem | precipm
# 2016-05-01 | 34        | -1         | 1005.63       | 24          | 4           | 43       | 26       | 9         | -10       | 1009         | 999          | 0
# 2016-05-02 | 36        | 4          | 1005.46       | 21          | 6           | 43       | 29       | 10        | -2        | 1008         | 1001         | 0
# 2016-05-03 | 35        | 6          | 1006          | 27          | 5           | 41       | 29       | 12        | -2        | 1009         | 1000         | 0
# 2016-05-04 | 34        | 7          | 1005.65       | 29          | 6           | 41       | 27       | 13        | 0         | 1008         | 1001         | 0
# 2016-05-05 | 31        | 11         | 1007.94       | 61          | 13          | 38       | 24       | 16        | 6         | 1011         | 1003         | 5
# 2016-05-06 | 28        | 13         | 1008.39       | 69          | 18          | 34       | 21       | 17        | 9         | 1011         | 1004         | 0
# 2016-05-07 | 30        | 10         | 1007.62       | 50          | 8           | 38       | 23       | 14        | 6         | 1010         | 1002         | 0
# 2016-05-08 | 34        | 8          | 1006.73       | 32          | 7           | 41       | 26       | 12        | 6         | 1010         | 1002         | 0
# 2016-05-09 | 34        | 11         | 1005.75       | 45          | 7           | 42       | 27       | 16        | 7         | 1008         | 1000         | 0.3
# 2016-05-10 | 34        | 16         | 1007.1        | 51          | 12          | 41       | 27       | 18        | 13        | 1010         | 1002         | 0.8
# ... (669 rows omitted)

# %%
# can mintempm predict maxtempm?

x, y = jaipur.column(5), jaipur.column(4)
correlation(x,y), slope(x, y), intercept(x, y)
# Out:
# (0.771550018914818, 0.8829650544838457, 47.1844677888961)

# %%
jaipur.scatter(5, 4, fit_line=True)
